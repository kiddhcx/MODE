# %% [markdown]
# <a href="https://colab.research.google.com/github/kiddhcx/MODE/blob/master/MODE1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # MODE

# %%
import tensorflow as tf
import keras as k
import numpy as np
import matplotlib.pyplot as plt

# personal modules
from distance_metrics import bhattacharyya
from eval import get_eval_datasets, replicate_model
from layer_selection import (Forward_Layer_Select, 
                                calculate_acc_for_labels, 
                                get_overfit_labels, 
                                get_underfit_labels,
                                get_faultiest_label)
from heatmap import get_heatmaps
from input_selection import select_next_inputs
from visualizations import (get_plot, 
                               visualize_array, 
                               get_samples_for_label,
                               sample_misclassifications, 
                               viz_heatmaps_for_correct_prediction, 
                               viz_heatmaps_for_false_positives, 
                               viz_heatmaps_for_false_negatives,
                               DHCI_i_k,
                               DHMI_i,
                               DHWI_i,
                               viz_most_least_similar,
                               viz_most_similar,
                               viz_least_similar)

# plot defaults
# %matplotlib inline
plt.rcParams['figure.figsize'] = (5.0, 4.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import sys
sys.path.insert(0,'/content/drive/My Drive/MODE')

# %% [markdown]
# ### References

# %% [markdown]
# https://stackoverflow.com/questions/41711190/keras-how-to-get-the-output-of-each-layer
# https://keras.io/getting-started/faq/#how-can-i-freeze-keras-layers

# %% [markdown]
# ### Parameters

# %%
# Underfitting Threshold
# Both the training accuracy (TrAcc)  and the testing accuracy (TeAcc)
# must be lower than this param to qualify as underfitting
theta = 0.96

# Overfitting Threshold
# The difference between the training accuracy (TrAcc) and testing accuracy (TeAcc)
# must be larger than this param to qualify as overfitting
gamma = 0.10

# Ratio between Selected Data and Random Data 
# Controls the ratio of the target class to fix and the random other classes 
# trained simultaneosly. 
# TODO: find a way to experiment with setting this automatically based on the 
# number of classes in your task. 
# TODO: see if we can use larger alpha and reduced batch sizes to control overfitting
alpha = 0.25

# Byattacharyya Distance
# If the distribution of two y_pred matrices are less than this amount, than they are
# sufficiently similar and we'll take the layer that produced the distribution first
similarity_threshold = 0.01

# Number of Epochs
# TODO: implement early stopping
epochs = 3

# Batch Size
batch_size = 2000 # they used 2000 and 4000 in the paper

# %% [markdown]
# ### Data

# %%
# download MNIST
mnist = tf.keras.datasets.mnist

# split into test and train sets
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# normalize to [0,1] by dividing by the max value
x_train, x_test = x_train / 255.0, x_test / 255.0

# further split x_train and y_train into new training and bug fixing sets (50/50)
from sklearn.model_selection import train_test_split
x_train, x_bug_fixes, y_train, y_bug_fixes = train_test_split(x_train, y_train, test_size=0.5, random_state=123)

print('Training data shape: ', x_train.shape)
print('Training labels shape: ', y_train.shape)

print('Bug Fixing data shape: ', x_bug_fixes.shape)
print('Bug Fixing labels shape: ', y_bug_fixes.shape)

print('Test data shape: ', x_test.shape)
print('Test labels shape: ', y_test.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 11501568/11490434 [==============================] - 0s 0us/step
# Training data shape:  (30000, 28, 28)
# Training labels shape:  (30000,)
# Bug Fixing data shape:  (30000, 28, 28)
# Bug Fixing labels shape:  (30000,)
# Test data shape:  (10000, 28, 28)
# Test labels shape:  (10000,)

# %% [markdown]
# ## Evaluation Model

# %% [markdown]
# Create a model that will be the one evaluated and retrained using MODE input selection.

# %%
# create model layers
model = k.models.Sequential([
  # flatten into a single vector
  k.layers.Flatten(input_shape=(28, 28)),
  # first layer
  k.layers.Dense(28, activation=tf.nn.relu),
  #k.layers.Dropout(0.2),
  # second layer
  k.layers.Dense(28, activation=tf.nn.relu),
  #k.layers.Dropout(0.2),
  # third layer
  k.layers.Dense(28, activation=tf.nn.relu),
  #k.layers.Dropout(0.2),
  # fourth layer
  #k.layers.Dense(28, activation=tf.nn.relu),
  #k.layers.Dropout(0.2),
  # output layer
  k.layers.Dense(10, activation=tf.nn.softmax)
])

# compile with optimizer, loss, and metrics
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
# fit
model.fit(x_train, y_train, epochs=epochs)
# Out:
# Epoch 1/3
# 938/938 [==============================] - 3s 3ms/step - loss: 0.4883 - accuracy: 0.8543
# Epoch 2/3
# 938/938 [==============================] - 2s 2ms/step - loss: 0.2091 - accuracy: 0.9400
# Epoch 3/3
# 938/938 [==============================] - 2s 2ms/step - loss: 0.1667 - accuracy: 0.9513

# %%
# predict train (to get distributions)
y_pred_train = model.predict(x_train)

# predict test (to get distributions)
y_pred = model.predict(x_test)

# %%
# final train
train_loss, train_acc = model.evaluate(x_train, y_train)
print('Train Loss: {}, Train Accuracy: {}'.format(train_loss, train_acc))

# test
test_loss, test_acc = model.evaluate(x_test, y_test)
print('Test Loss: {}, Test Accuracy: {}'.format(test_loss, test_acc))
# Out:
# 938/938 [==============================] - 2s 2ms/step - loss: 0.1370 - accuracy: 0.9607
# Train Loss: 0.13704964518547058, Train Accuracy: 0.9607333540916443
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1688 - accuracy: 0.9511
# Test Loss: 0.16875211894512177, Test Accuracy: 0.9510999917984009

# %% [markdown]
# ## Control Model

# %% [markdown]
# Create a model that will be retrained on a similar amount of data but as our main model, but the data is chosen at random.

# %%
control_model = replicate_model(model)

control_model.compile(optimizer='adam',
                      loss='sparse_categorical_crossentropy',
                      metrics=['accuracy'])

# control_model.build()
# control_model.summary()

# %% [markdown]
# ## Targeting Problematic Layers

# %%
use_target_layer = True

# %%
target_layer, cache = Forward_Layer_Select(model, 
                                           x_train, 
                                           y_train, 
                                           x_test, 
                                           y_test, 
                                           epochs, 
                                           similarity_threshold, 
                                           verbose=False)
# Out:
# Target Layer # 4: <keras.layers.core.dense.Dense object at 0x7f08351855d0>

# %%
feature_models, accuracies, bhattacharyyas, layer_pred = cache

get_plot(accuracies, 
         title='Number of Layers and Accuracy',
         xlabel='Number of layers',
         ylabel='Accuracy')

get_plot(bhattacharyyas, 
         title='Number of Layers and Bhattacharyya Similarity',
         xlabel='Number of layers',
         ylabel='Bhattacharyya Similarity')

visualize_array(target_layer.get_weights()[0])

# %% [markdown]
# ## Training Set Results

# %%
# NOTE: _o means correct and _x means incorrect and can be read as
#       "for those that were incorrectly classified"

out = get_eval_datasets(data = x_train, 
                        labels = y_train, 
                        predictions = y_pred_train)

x_train_o, y_pred_train_o, x_train_x, y_pred_train_x, y_true_train_x = out

# %%
num_classes = 10
accuracies_per_label_train = calculate_acc_for_labels(all_labels = y_train,
                                                      correct_labels = y_pred_train_o,
                                                      num_classes = num_classes,
                                                      labels = [])

# %%
accuracies_per_label_train
# Out:
# {0: 0.9752425560388089,
#  1: 0.9815950920245399,
#  2: 0.9494814319170292,
#  3: 0.9567071170875697,
#  4: 0.9556313993174061,
#  5: 0.978486646884273,
#  6: 0.9594686648501363,
#  7: 0.967176545570427,
#  8: 0.9447684391080617,
#  9: 0.9362644853442399}

# %% [markdown]
# ## Test Set Results

# %%
# NOTE: _o means correct and _x means incorrect and can be read as
#       "for those that were incorrectly classified"

out = get_eval_datasets(data = x_test, 
                        labels = y_test, 
                        predictions = y_pred)

x_test_o, y_pred_o, x_test_x, y_pred_x, y_true_x = out

# %%
accuracies_per_label_test = calculate_acc_for_labels(all_labels = y_test,
                                                     correct_labels = y_pred_o,
                                                     num_classes = num_classes,
                                                     labels = [])

# %%
accuracies_per_label_test
# Out:
# {0: 0.9673469387755103,
#  1: 0.9841409691629956,
#  2: 0.9418604651162791,
#  3: 0.9524752475247524,
#  4: 0.955193482688391,
#  5: 0.9697309417040358,
#  6: 0.941544885177453,
#  7: 0.9542356377799416,
#  8: 0.917864476386037,
#  9: 0.9236868186323092}

# %% [markdown]
# ## Identify Problematic Labels

# %%
underfit_labels = get_underfit_labels(acc = accuracies_per_label_train,
                                      num_classes = num_classes,
                                      threshold = theta,
                                      labels = []) 

print(underfit_labels)
# Out:
# {2: 0.9494814319170292, 3: 0.9567071170875697, 4: 0.9556313993174061, 6: 0.9594686648501363, 8: 0.9447684391080617, 9: 0.9362644853442399}

# %%
get_faultiest_label(underfit_labels)
# Out:
# 9

# %%
overfit_labels = get_overfit_labels(train_acc = accuracies_per_label_train,
                                    test_acc = accuracies_per_label_test,
                                    num_classes = num_classes,
                                    threshold = gamma,
                                    labels = [])

print(overfit_labels)
# Out:
# No overfit labels...
# {}

# %% [markdown]
# ## Get Heatmaps

# %%
labels, heatmaps = get_heatmaps(correct_data = x_test_o,
                                correct_labels = y_pred_o,
                                misclassified_data = x_test_x, 
                                misclassified_labels = y_pred_x, 
                                misclassified_correct_labels = y_true_x, 
                                num_classes = num_classes,
                                labels = [], 
                                type = 'hci')

# %% [markdown]
# ## Get Next Batch

# %%
next_X, next_y, x_bug_fixes, y_bug_fixes = select_next_inputs(bug_fix_data = x_bug_fixes,
                                                              bug_fix_labels = y_bug_fixes,
                                                              heatmaps = heatmaps,
                                                              target_label = 1,
                                                              batch_size = batch_size,
                                                              ratio = alpha,
                                                              for_underfitting=True,
                                                              distance_metric='dot')
# check out an example of a desirable target
print(next_y[0])
visualize_array(next_X[0])
# Out:
# Bug Fixing Pool - # of samples remaining: 28000
# 1

# %% [markdown]
# ## Targeted Label Retraining

# %% [markdown]
# 0. Train model on all training data and evaluate performance on test data.
#
#
# 1. Starting with underfitting first, select the target layer that enters a saturation point.
# 2. Use the predictions of the target layer, generate heatmaps for each label.
# 3. Calculate the per-label accuracy.
# 4. Select the most faulty label for retraining (break if none).
# 5. Generate a batch tailored to improving performance on that label.
# 6. Train on this new batch
# 7. Evaluate performance
# 8. Return to 1 and repeat until there are no more faulty underfitting labels
#
#
# 9. Select the most faulty overfitting label
# 10. Use the predictions of the target layer, generate heatmaps for each label.
# 11. Calculate the per-label accuracy.
# 12. Select the most faulty label for retraining (break if none).
# 13. Generate a batch tailored to improving performance on that label.
# 14. Train on this new batch
# 15. Evaluate performance
# 16. Return to 1 and repeat until there are no more faulty underfitting labels
#
#
# 17. Check if there are anymore underfitting labels, if so, return to 1

# %%
max_iter = 5

distance_metrics = ['dot', 'cosine', 'manhattan', 'euclidean', 'minkowski', 'earthmover', 'chebyshev', 'canberra', 'braycurtis']

for distance_metric in distance_metrics:
    
    print('#####################################################################')
    print('Testing: {} similarity'.format(distance_metric))
    print('#####################################################################')
    
    # download MNIST
    mnist = tf.keras.datasets.mnist

    # split into test and train sets
    (x_train, y_train), (x_test, y_test) = mnist.load_data()

    # normalize to [0,1] by dividing by the max value
    x_train, x_test = x_train / 255.0, x_test / 255.0

    # further split x_train and y_train into new training and bug fixing sets (50/50)
    from sklearn.model_selection import train_test_split
    x_train, x_bug_fixes, y_train, y_bug_fixes = train_test_split(x_train, y_train, test_size=0.5, random_state=123)

    print('Training data shape: ', x_train.shape)
    print('Training labels shape: ', y_train.shape)

    print('Bug Fixing data shape: ', x_bug_fixes.shape)
    print('Bug Fixing labels shape: ', y_bug_fixes.shape)

    print('Test data shape: ', x_test.shape)
    print('Test labels shape: ', y_test.shape)

    # create model layers
    model = k.models.Sequential([
      # flatten into a single vector
      k.layers.Flatten(input_shape=(28, 28)),
      # first layer
      k.layers.Dense(28, activation=tf.nn.relu),
      #k.layers.Dropout(0.2),
      # second layer
      k.layers.Dense(28, activation=tf.nn.relu),
      #k.layers.Dropout(0.2),
      # third layer
      #k.layers.Dense(28, activation=tf.nn.relu),
      #k.layers.Dropout(0.2),
      # fourth layer
      #k.layers.Dense(28, activation=tf.nn.relu),
      #k.layers.Dropout(0.2),
      # output layer
      k.layers.Dense(10, activation=tf.nn.softmax)
    ])

    # compile with optimizer, loss, and metrics
    model.compile(optimizer='adam',
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])

    # fit
    model.fit(x_train, y_train, epochs=epochs)

    # predict test (to get distributions)
    y_pred = model.predict(x_test)

    # test
    test_loss, test_acc = model.evaluate(x_test, y_test, verbose=0)
    print('Initial Test Loss: {}, Initial Test Accuracy: {}'.format(test_loss, test_acc))

    control_model = replicate_model(model)

    control_model.compile(optimizer='adam',
                          loss='sparse_categorical_crossentropy',
                          metrics=['accuracy'])

    i = 0
    while i < max_iter:

        # control model with no specialized batch selection
        control_batch_x, control_batch_y = x_bug_fixes[:batch_size], y_bug_fixes[:batch_size]
        control_model.fit(control_batch_x, control_batch_y, epochs=epochs, verbose=0)

        # identify target layer
        print('Identifying target layer...')
        target_layer, cache = Forward_Layer_Select(model, 
                                                   x_train, 
                                                   y_train, 
                                                   x_test, 
                                                   y_test, 
                                                   epochs, 
                                                   similarity_threshold, 
                                                   verbose=False)

        feature_models, accuracies, bhattacharyyas, layer_pred = cache

        # breakout eval sets
        out = get_eval_datasets(data = x_test, 
                                labels = y_test, 
                                predictions = layer_pred)

        data_correct, labels_correct, data_incorrect, labels_incorrect, labels_corrected = out

        # generate heatmaps
        labels, heatmaps = get_heatmaps(correct_data = data_correct,
                                        correct_labels = labels_correct,
                                        misclassified_data = data_incorrect, 
                                        misclassified_labels = labels_incorrect, 
                                        misclassified_correct_labels = labels_corrected, 
                                        num_classes = num_classes,
                                        labels = [], 
                                        type = 'hci')

        # identify buggy labels
        accuracies_per_label_target = calculate_acc_for_labels(all_labels = y_test,
                                                               correct_labels = labels_correct,
                                                               num_classes = num_classes,
                                                               labels = [])

        underfit_labels = get_underfit_labels(acc = accuracies_per_label_target,
                                              num_classes = num_classes,
                                              threshold = theta,
                                              labels = []) 


        # select the most faulty underfitting label
        if len(underfit_labels) > 0:
            faultiest_label = get_faultiest_label(underfit_labels)
            print('Creating a batch for faultiest label: {}. There are {} faulty labels in total...'.format(faultiest_label, 
                                                                                                           len(underfit_labels)))
            print('Faulty labels: ', underfit_labels)
        else:
            print('MODE retraining complete!')
            break

        # generate a batch tailored to improving performance on that label
        next_X, next_y, x_bug_fixes, y_bug_fixes = select_next_inputs(bug_fix_data = x_bug_fixes,
                                                                      bug_fix_labels = y_bug_fixes,
                                                                      heatmaps = heatmaps,
                                                                      target_label = faultiest_label,
                                                                      batch_size = batch_size,
                                                                      ratio = alpha,
                                                                      for_underfitting = True,
                                                                      distance_metric = distance_metric)

        # train on this new batch
        model.fit(next_X, next_y, epochs=epochs, verbose=1)

        # evaluate performance
        test_loss, test_acc = model.evaluate(x_test, y_test, verbose=0)
        print('Test Loss: {}, Test Accuracy: {}'.format(test_loss, test_acc))

        # repeat until there are no more faulty underfitting labels
        i += 1

        print('{} iterations left...\n'.format(max_iter - i))

    print('Control model performance to beat:')  
    control_loss, control_acc = control_model.evaluate(x_test, y_test, verbose=0)
    print('Control Test Loss: {}, Control Test Accuracy: {}'.format(control_loss, control_acc))
# Out:
# #####################################################################
# Testing: dot similarity
# #####################################################################
# Training data shape:  (30000, 28, 28)
# Training labels shape:  (30000,)
# Bug Fixing data shape:  (30000, 28, 28)
# Bug Fixing labels shape:  (30000,)
# Test data shape:  (10000, 28, 28)
# Test labels shape:  (10000,)
# Epoch 1/3
# 938/938 [==============================] - 3s 2ms/step - loss: 0.4826 - accuracy: 0.8608
# Epoch 2/3
# 938/938 [==============================] - 2s 2ms/step - loss: 0.2401 - accuracy: 0.9289
# Epoch 3/3
# 938/938 [==============================] - 2s 2ms/step - loss: 0.1889 - accuracy: 0.9450
# Initial Test Loss: 0.1870810091495514, Initial Test Accuracy: 0.9440000057220459
# Identifying target layer...
# Target Layer is the Output Layer: <keras.layers.core.dense.Dense object at 0x7f0826b78590>.
#  Consider additional training because performance has not yet plateued.
# Creating a batch for faultiest label: 5. There are 8 faulty labels in total...
# Faulty labels:  {2: 0.9292635658914729, 3: 0.902970297029703, 4: 0.9490835030549898, 5: 0.8957399103139013, 6: 0.9509394572025052, 7: 0.9483933787731256, 8: 0.9342915811088296, 9: 0.9326065411298315}
# Bug Fixing Pool - # of samples remaining: 28000
# Epoch 1/3
# 63/63 [==============================] - 0s 2ms/step - loss: 0.1817 - accuracy: 0.9405
# Epoch 2/3
# 63/63 [==============================] - 0s 2ms/step - loss: 0.1299 - accuracy: 0.9565
# Epoch 3/3
# 63/63 [==============================] - 0s 2ms/step - loss: 0.1058 - accuracy: 0.9650
# Test Loss: 0.21355991065502167, Test Accuracy: 0.9337000250816345
# 4 iterations left...
#
# Identifying target layer...
# Target Layer is the Output Layer: <keras.layers.core.dense.Dense object at 0x7f0826b78590>.
#  Consider additional training because performance has not yet plateued.
# Creating a batch for faultiest label: 5. There are 8 faulty labels in total...
# Faulty labels:  {2: 0.9253875968992248, 3: 0.9267326732673268, 4: 0.955193482688391, 5: 0.9024663677130045, 6: 0.9509394572025052, 7: 0.9444985394352483, 8: 0.9117043121149897, 9: 0.9187314172447968}
# Bug Fixing Pool - # of samples remaining: 26000
# Epoch 1/3
# 63/63 [==============================] - 0s 3ms/step - loss: 0.1906 - accuracy: 0.9450
# Epoch 2/3
# 63/63 [==============================] - 0s 2ms/step - loss: 0.1342 - accuracy: 0.9620
# Epoch 3/3
# 63/63 [==============================] - 0s 2ms/step - loss: 0.1116 - accuracy: 0.9700
# Test Loss: 0.19320537149906158, Test Accuracy: 0.9448000192642212
# 3 iterations left...
#
# Identifying target layer...
# Target Layer is the Output Layer: <keras.layers.core.dense.Dense object at 0x7f0826b78590>.
#  Consider additional training because performance has not yet plateued.
# Creating a batch for faultiest label: 5. There are 6 faulty labels in total...
# Faulty labels:  {2: 0.938953488372093, 3: 0.9316831683168317, 5: 0.8856502242152466, 7: 0.952288218111003, 8: 0.9219712525667351, 9: 0.9117938553022795}
# Bug Fixing Pool - # of samples remaining: 24000
# Epoch 1/3
# 63/63 [==============================] - 0s 3ms/step - loss: 0.1778 - accuracy: 0.9420
# Epoch 2/3
# 63/63 [==============================] - 0s 3ms/step - loss: 0.1297 - accuracy: 0.9595
# Epoch 3/3
# 63/63 [==============================] - 0s 3ms/step - loss: 0.1031 - accuracy: 0.9740
# Test Loss: 0.18815724551677704, Test Accuracy: 0.9413999915122986
# 2 iterations left...
#
# Identifying target layer...
# Target Layer is the Output Layer: <keras.layers.core.dense.Dense object at 0x7f0826b78590>.
#  Consider additional training because performance has not yet plateued.
# Creating a batch for faultiest label: 3. There are 8 faulty labels in total...
# Faulty labels:  {2: 0.938953488372093, 3: 0.9099009900990099, 4: 0.9419551934826884, 5: 0.922645739910314, 6: 0.9446764091858038, 7: 0.943524829600779, 8: 0.9271047227926078, 9: 0.9365708622398414}
# Bug Fixing Pool - # of samples remaining: 22000
# Epoch 1/3
# 63/63 [==============================] - 0s 2ms/step - loss: 0.1914 - accuracy: 0.9440
# Epoch 2/3
# 63/63 [==============================] - 0s 2ms/step - loss: 0.1381 - accuracy: 0.9630
# Epoch 3/3
# 63/63 [==============================] - 0s 2ms/step - loss: 0.1011 - accuracy: 0.9730
# Test Loss: 0.19457802176475525, Test Accuracy: 0.9417999982833862
# 1 iterations left...
#
# Identifying target layer...
# Target Layer is the Output Layer: <keras.layers.core.dense.Dense object at 0x7f0826b78590>.
#  Consider additional training because performance has not yet plateued.
# Creating a batch for faultiest label: 9. There are 6 faulty labels in total...
# Faulty labels:  {2: 0.937015503875969, 3: 0.9247524752475248, 5: 0.9181614349775785, 7: 0.952288218111003, 8: 0.9117043121149897, 9: 0.910802775024777}
# Bug Fixing Pool - # of samples remaining: 20000
# Epoch 1/3
# 63/63 [==============================] - 0s 3ms/step - loss: 0.
# Epoch 2/3
# 63/63 [==============================] - 0s 3ms/step - loss: 0.1242 - accuracy: 0.9675
# Epoch 3/3
# 63/63 [==============================] - 0s 3ms/step - loss: 0.0944 - accuracy: 0.9775
# Test Loss: 0.1778315007686615, Test Accuracy: 0.9492999911308289
# 0 iterations left...
#
# Control model performance to beat:
# Control Test Loss: 0.178018257021904, Control Test Accuracy: 0.9447000026702881

# %%
max_iter = 5

distance_metrics = ['dot', 'cosine', 'manhattan', 'euclidean', 'minkowski', 'earthmover', 'chebyshev', 'canberra', 'braycurtis']

for distance_metric in distance_metrics:
    
    print('#####################################################################')
    print('Testing: {} similarity'.format(distance_metric))
    print('#####################################################################')
    
    # download MNIST
    mnist = tf.keras.datasets.mnist

    # split into test and train sets
    (x_train, y_train), (x_test, y_test) = mnist.load_data()

    # normalize to [0,1] by dividing by the max value
    x_train, x_test = x_train / 255.0, x_test / 255.0

    # further split x_train and y_train into new training and bug fixing sets (50/50)
    from sklearn.model_selection import train_test_split
    x_train, x_bug_fixes, y_train, y_bug_fixes = train_test_split(x_train, y_train, test_size=0.5, random_state=123)

    print('Training data shape: ', x_train.shape)
    print('Training labels shape: ', y_train.shape)

    print('Bug Fixing data shape: ', x_bug_fixes.shape)
    print('Bug Fixing labels shape: ', y_bug_fixes.shape)

    print('Test data shape: ', x_test.shape)
    print('Test labels shape: ', y_test.shape)

    # create model layers
    model = k.models.Sequential([
      # flatten into a single vector
      k.layers.Flatten(input_shape=(28, 28)),
      # first layer
      k.layers.Dense(28, activation=tf.nn.relu),
      #k.layers.Dropout(0.2),
      # second layer
      k.layers.Dense(28, activation=tf.nn.relu),
      #k.layers.Dropout(0.2),
      # third layer
      #k.layers.Dense(28, activation=tf.nn.relu),
      #k.layers.Dropout(0.2),
      # fourth layer
      #k.layers.Dense(28, activation=tf.nn.relu),
      #k.layers.Dropout(0.2),
      # output layer
      k.layers.Dense(10, activation=tf.nn.softmax)
    ])

    # compile with optimizer, loss, and metrics
    model.compile(optimizer='adam',
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])

    # fit
    model.fit(x_train, y_train, epochs=epochs)

    # predict test (to get distributions)
    y_pred = model.predict(x_test)

    # test
    test_loss, test_acc = model.evaluate(x_test, y_test, verbose=0)
    print('Initial Test Loss: {}, Initial Test Accuracy: {}'.format(test_loss, test_acc))

    control_model = replicate_model(model)

    control_model.compile(optimizer='adam',
                          loss='sparse_categorical_crossentropy',
                          metrics=['accuracy'])


    i = 0
    while i < max_iter:

        # control model with no specialized batch selection
        control_batch_x, control_batch_y = x_bug_fixes[:batch_size], y_bug_fixes[:batch_size]
        control_model.fit(control_batch_x, control_batch_y, epochs=epochs, verbose=0)

        # breakout eval sets
        out = get_eval_datasets(data = x_test, 
                                labels = y_test, 
                                predictions = y_pred)

        data_correct, labels_correct, data_incorrect, labels_incorrect, labels_corrected = out

        # generate heatmaps
        labels, heatmaps = get_heatmaps(correct_data = data_correct,
                                        correct_labels = labels_correct,
                                        misclassified_data = data_incorrect, 
                                        misclassified_labels = labels_incorrect, 
                                        misclassified_correct_labels = labels_corrected, 
                                        num_classes = num_classes,
                                        labels = [], 
                                        type = 'hci')

        # identify buggy labels
        accuracies_per_label_target = calculate_acc_for_labels(all_labels = y_test,
                                                               correct_labels = labels_correct,
                                                               num_classes = num_classes,
                                                               labels = [])

        underfit_labels = get_underfit_labels(acc = accuracies_per_label_target,
                                              num_classes = num_classes,
                                              threshold = theta,
                                              labels = []) 


        # select the most faulty underfitting label
        if len(underfit_labels) > 0:
            faultiest_label = get_faultiest_label(underfit_labels)
            print('Creating a batch for faultiest label: {}. There are {} faulty labels in total...'.format(faultiest_label, 
                                                                                                           len(underfit_labels)))
            print('Faulty labels: ', underfit_labels)
        else:
            print('MODE retraining complete!')
            break

        # generate a batch tailored to improving performance on that label
        next_X, next_y, x_bug_fixes, y_bug_fixes = select_next_inputs(bug_fix_data = x_bug_fixes,
                                                                      bug_fix_labels = y_bug_fixes,
                                                                      heatmaps = heatmaps,
                                                                      target_label = faultiest_label,
                                                                      batch_size = batch_size,
                                                                      ratio = alpha,
                                                                      for_underfitting=True,
                                                                      distance_metric=distance_metric)

        # train on this new batch
        model.fit(next_X, next_y, epochs=epochs, verbose=1)

        # make predictions
        y_pred = model.predict(x_test)

        # evaluate performance
        test_loss, test_acc = model.evaluate(x_test, y_test, verbose=0)
        print('Test Loss: {}, Test Accuracy: {}'.format(test_loss, test_acc))

        # repeat until there are no more faulty underfitting labels
        i += 1

        print('{} iterations left...\n'.format(max_iter - i))

    print('Control model performance to beat:')  
    control_loss, control_acc = control_model.evaluate(x_test, y_test, verbose=0)
    print('Control Test Loss: {}, Control Test Accuracy: {}'.format(control_loss, control_acc))
# Out:
# #####################################################################
# Testing: dot similarity
# #####################################################################
# Training data shape:  (30000, 28, 28)
# Training labels shape:  (30000,)
# Bug Fixing data shape:  (30000, 28, 28)
# Bug Fixing labels shape:  (30000,)
# Test data shape:  (10000, 28, 28)
# Test labels shape:  (10000,)
# Epoch 1/3
# 938/938 [==============================] - 3s 2ms/step - loss: 0.4842 - accuracy: 0.8586
# Epoch 2/3
# 938/938 [==============================] - 3s 3ms/step - loss: 0.2315 - accuracy: 0.9325
# Epoch 3/3
# 938/938 [==============================] - 2s 2ms/step - loss: 0.1826 - accuracy: 0.9462
# Initial Test Loss: 0.17486831545829773, Initial Test Accuracy: 0.9465000033378601
# Creating a batch for faultiest label: 3. There are 8 faulty labels in total...
# Faulty labels:  {2: 0.938953488372093, 3: 0.9128712871287129, 4: 0.9389002036659878, 5: 0.9170403587443946, 6: 0.9436325678496869, 7: 0.9483933787731256, 8: 0.9383983572895277, 9: 0.9484638255698712}
# Bug Fixing Pool - # of samples remaining: 28000
# Epoch 1/3
# 63/63 [==============================] - 0s 2ms/step - loss: 0.1720 - accuracy: 0.9430
# Epoch 2/3
# 63/63 [==============================] - 0s 2ms/step - loss: 0.1217 - accuracy: 0.9580
# Epoch 3/3
# 63/63 [==============================] - 0s 2ms/step - loss: 0.0971 - accuracy: 0.9720
# Test Loss: 0.1902538388967514, Test Accuracy: 0.9430999755859375
# 4 iterations left...
#
# Creating a batch for faultiest label: 8. There are 7 faulty labels in total...
# Faulty labels:  {2: 0.9282945736434108, 3: 0.9306930693069307, 4: 0.9460285132382892, 5: 0.9136771300448431, 7: 0.9337877312560857, 8: 0.9014373716632443, 9: 0.9395441030723488}
# Bug Fixing Pool - # of samples remaining: 26000
# Epoch 1/3
# 63/63 [==============================] - 0s 2ms/step - loss: 0.1615 - accuracy: 0.9465
# Epoch 2/3
# 63/63 [==============================] - 0s 3ms/step - loss: 0.1120 - accuracy: 0.9655
# Epoch 3/3
# 63/63 [==============================] - 0s 2ms/step - loss: 0.0953 - accuracy: 0.9730
# Test Loss: 0.19586947560310364, Test Accuracy: 0.9419999718666077
# 3 iterations left...
#
# Creating a batch for faultiest label: 5. There are 8 faulty labels in total...
# Faulty labels:  {2: 0.9496124031007752, 3: 0.9316831683168317, 4: 0.924643584521385, 5: 0.8934977578475336, 6: 0.9478079331941545, 7: 0.9221032132424537, 8: 0.919917864476386, 9: 0.9405351833498513}
# Bug Fixing Pool - # of samples remaining: 24000
# Epoch 1/3
# 63/63 [==============================] - 0s 2ms/step - loss: 0.1618 - accuracy: 0.9485
# Epoch 2/3
# 63/63 [==============================] - 0s 3ms/step - loss: 0.1112 - accuracy: 0.9660
# Epoch 3/3
# 63/63 [==============================] - 0s 3ms/step - loss: 0.0801 - accuracy: 0.9770
# Test Loss: 0.18583548069000244, Test Accuracy: 0.9455999732017517
# 2 iterations left...
#
# Creating a batch for faultiest label: 3. There are 8 faulty labels in total...
# Faulty labels:  {2: 0.9437984496124031, 3: 0.9128712871287129, 4: 0.9470468431771895, 5: 0.952914798206278, 6: 0.941544885177453, 7: 0.9298928919182083, 8: 0.9281314168377823, 9: 0.931615460852329}
# Bug Fixing Pool - # of samples remaining: 22000
# Epoch 1/3
# 63/63 [==============================] - 0s 2ms/step - loss: 0.1888 - accuracy: 0.9400
# Epoch 2/3
# 63/63 [==============================] - 0s 3ms/step - loss: 0.1279 - accuracy: 0.9605
# Epoch 3/3
# 63/63 [==============================] - 0s 2ms/step - loss: 0.
# Epoch 3/3
# 63/63 [==============================] - 0s 3ms/step - loss: 0.1103 - accuracy: 0.9685
# Test Loss: 0.1997951716184616, Test Accuracy: 0.9412999749183655
# 1 iterations left...
#
# Creating a batch for faultiest label: 3. There are 6 faulty labels in total...
# Faulty labels:  {2: 0.9534883720930233, 3: 0.8762376237623762, 5: 0.9237668161434978, 7: 0.9396299902629016, 8: 0.9425051334702259, 9: 0.8949454905847374}
# Bug Fixing Pool - # of samples remaining: 20000
# Epoch 1/3
# 63/63 [==============================] - 0s 3ms/step - loss: 0.2434 - accuracy: 0.9285
# Epoch 2/3
# 63/63 [==============================] - 0s 3ms/step - loss: 0.1632 - accuracy: 0.9510
# Epoch 3/3
# 63/63 [==============================] - 0s 3ms/step - loss: 0.1230 - accuracy: 0.9645
# Test Loss: 0.20846033096313477, Test Accuracy: 0.9409999847412109
# 0 iterations left...
#
# Control model performance to beat:
# Control Test Loss: 0.19846245646476746, Control Test Accuracy: 0.9438999891281128
# #####################################################################
# Testing: chebyshev similarity
# #####################################################################
# Training data shape:  (30000, 28, 28)
# Training labels shape:  (30000,)
# Bug Fixing data shape:  (30000, 28, 28)
# Bug Fixing labels shape:  (30000,)
# Test data shape:  (10000, 28, 28)
# Test labels shape:  (10000,)
# Epoch 1/3
# 938/938 [==============================] - 3s 3ms/step - loss: 0.4607 - accuracy: 0.8693
# Epoch 2/3
# 938/938 [==============================] - 3s 3ms/step - loss: 0.2284 - accuracy: 0.9344
# Epoch 3/3
# 938/938 [==============================] - 3s 3ms/step - loss: 0.1789 - accuracy: 0.9474
# Initial Test Loss: 0.18076227605342865, Initial Test Accuracy: 0.9448000192642212
# Creating a batch for faultiest label: 3. There are 6 faulty labels in total...
# Faulty labels:  {2: 0.9437984496124031, 3: 0.8851485148514852, 4: 0.9592668024439919, 5: 0.8957399103139013, 8: 0.9363449691991786, 9: 0.9207135777998018}
# Bug Fixing Pool - # of samples remaining: 28000
# Epoch 1/3
# 63/63 [==============================] - 0s 3ms/step - loss: 0.1362 - accuracy: 0.9615
# Epoch 2/3
# 63/63 [==============================] - 0s 3ms/step - loss: 0.0985 - accuracy: 0.9760
# Epoch 3/3
# 63/63 [==============================] - 0s 3ms/step - loss: 0.0828 - accuracy: 0.9825
# Test Loss: 0.19033028185367584, Test Accuracy: 0.9426000118255615
# 4 iterations left...
#
# Creating a batch for faultiest label: 3. There are 7 faulty labels in total...
# Faulty labels:  {2: 0.9534883720930233, 3: 0.8762376237623762, 4: 0.9348268839103869, 5: 0.9091928251121076, 7: 0.9581304771178188, 8: 0.9414784394250514, 9: 0.9345887016848364}
# Bug Fixing Pool - # of samples remaining: 26000
# Epoch 1/3
# 63/63 [==============================] - 0s 3ms/step - loss: 0.1366 - accuracy: 0.9605
# Epoch 2/3
# 63/63 [==============================] - 0s 3ms/step - loss: 0.0891 - accuracy: 0.9735
# Epoch 3/3
# 63/63 [==============================] - 0s 3ms/step - loss: 0.0748 - accuracy: 0.9775
# Test Loss: 0.18365387618541718, Test Accuracy: 0.9473000168800354
# 3 iterations left...
#
# Creating a batch for faultiest label: 3. There are 7 faulty labels in total...
# Faulty labels:  {2: 0.9554263565891473, 3: 0.8910891089108911, 4: 0.9521384928716904, 5: 0.9204035874439462, 7: 0.9406037000973709, 8: 0.9404517453798767, 9: 0.9395441030723488}
# Bug Fixing Pool - # of samples remaining: 24000
# Epoch 1/3
# 63/63 [==============================] - 0s 3ms/step - loss: 0.1631 - accuracy: 0.9500
# Epoch 2/3
# 63/63 [==============================] - 0s 3ms/step - loss: 0.1084 - accuracy: 0.9670
# Epoch 3/3
# 63/63 [==============================] - 0s 3ms/step - loss: 0.0829 - accuracy: 0.9770
# Test Loss: 0.18245713412761688, Test Accuracy: 0.9484000205993652
# 2 iterations left...
#
# Creating a batch for faultiest label: 3. There are 6 faulty labels in total...
# Faulty labels:  {2: 0.9583333333333334, 3: 0.9158415841584159, 5: 0.9170403587443946, 7: 0.937682570593963, 8: 0.9363449691991786, 9: 0.9306243805748265}
# Bug Fixing Pool - # of samples remaining: 22000
# Epoch 1/3
# 63/63 [==============================] - 0s 3ms/step - loss: 0.2018 - accuracy: 0.9430
# Epoch 2/3
# 63/63 [==============================] - 0s 2ms/step - loss: 0.1413 - accuracy: 0.9595
# Epoch 3/3
# 63/63 [==============================] - 0s 3ms/step - loss: 0.1034 - accuracy: 0.9700
# Test Loss: 0.17725755274295807, Test Accuracy: 0.9467999935150146
# 1 iterations left...
#
# Creating a batch for faultiest label: 8. There are 6 faulty labels in total...
# Faulty labels:  {2: 0.9428294573643411, 3: 0.9445544554455445, 5: 0.9282511210762332, 7: 0.943524829600779, 8: 0.9014373716632443, 9: 0.9038652130822596}
# Bug Fixing Pool - # of samples remaining: 20000
# Epoch 1/3
# 63/63 [==============================] - 0s 3ms/step - loss: 0.1820 - accuracy: 0.9530
# Epoch 2/3
# 63/63 [==============================] - 0s 3ms/step - loss: 0.1263 - accuracy: 0.9690
# Epoch 3/3
# 63/63 [==============================] - 0s 4ms/step - loss: 0.0885 - accuracy: 0.9770
# Test Loss: 0.2028798758983612, Test Accuracy: 0.9395999908447266
# 0 iterations left...
#
# Control model performance to beat:
# Control Test Loss: 0.1904931217432022, Control Test Accuracy: 0.9426000118255615
# #####################################################################
# Testing: canberra similarity
# #####################################################################
# Training data shape:  (30000, 28, 28)
# Training labels shape:  (30000,)
# Bug Fixing data shape:  (30000, 28, 28)
# Bug Fixing labels shape:  (30000,)
# Test data shape:  (10000, 28, 28)
# Test labels shape:  (10000,)
# Epoch 1/3
# 938/938 [==============================] - 3s 3ms/step - loss: 0.4903 - accuracy: 0.8642
# Epoch 2/3
# 938/938 [==============================] - 3s 3ms/step - loss: 0.
# Bug Fixing Pool - # of samples remaining: 26000
# Epoch 1/3
# 63/63 [==============================] - 0s 3ms/step - loss: 0.1604 - accuracy: 0.9475
# Epoch 2/3
# 63/63 [==============================] - 0s 3ms/step - loss: 0.1130 - accuracy: 0.9715
# Epoch 3/3
# 63/63 [==============================] - 0s 3ms/step - loss: 0.0909 - accuracy: 0.9760
# Test Loss: 0.19123362004756927, Test Accuracy: 0.9453999996185303
# 3 iterations left...
#
# Creating a batch for faultiest label: 5. There are 5 faulty labels in total...
# Faulty labels:  {2: 0.9312015503875969, 3: 0.9118811881188119, 5: 0.9024663677130045, 8: 0.9250513347022588, 9: 0.9266600594648167}
# Bug Fixing Pool - # of samples remaining: 24000
# Epoch 1/3
# 63/63 [==============================] - 0s 3ms/step - loss: 0.1524 - accuracy: 0.9540
# Epoch 2/3
# 63/63 [==============================] - 0s 3ms/step - loss: 0.0933 - accuracy: 0.9680
# Epoch 3/3
# 63/63 [==============================] - 0s 3ms/step - loss: 0.0724 - accuracy: 0.9770
# Test Loss: 0.18790976703166962, Test Accuracy: 0.944100022315979
# 2 iterations left...
#
# Creating a batch for faultiest label: 5. There are 8 faulty labels in total...
# Faulty labels:  {2: 0.9312015503875969, 3: 0.9227722772277228, 4: 0.939918533604888, 5: 0.8923766816143498, 6: 0.9551148225469729, 7: 0.9581304771178188, 8: 0.9271047227926078, 9: 0.9405351833498513}
# Bug Fixing Pool - # of samples remaining: 22000
# Epoch 1/3
# 63/63 [==============================] - 0s 3ms/step - loss: 0.1725 - accuracy: 0.9550
# Epoch 2/3
# 63/63 [==============================] - 0s 3ms/step - loss: 0.1238 - accuracy: 0.9675
# Epoch 3/3
# 63/63 [==============================] - 0s 3ms/step - loss: 0.0957 - accuracy: 0.9785
# Test Loss: 0.18665729463100433, Test Accuracy: 0.9448999762535095
# 1 iterations left...
#
# Creating a batch for faultiest label: 9. There are 6 faulty labels in total...
# Faulty labels:  {2: 0.9515503875968992, 3: 0.9178217821782179, 5: 0.9248878923766816, 7: 0.9474196689386563, 8: 0.9127310061601642, 9: 0.9098116947472745}
# Bug Fixing Pool - # of samples remaining: 20000
# Epoch 1/3
# 63/63 [==============================] - 0s 3ms/step - loss: 0.1441 - accuracy: 0.9585
# Epoch 2/3
# 63/63 [==============================] - 0s 3ms/step - loss: 0.0962 - accuracy: 0.9715
# Epoch 3/3
# 63/63 [==============================] - 0s 3ms/step - loss: 0.0725 - accuracy: 0.9820
# Test Loss: 0.18184033036231995, Test Accuracy: 0.9490000009536743
# 0 iterations left...
#
# Control model performance to beat:
# Control Test Loss: 0.17712391912937164, Control Test Accuracy: 0.9470999836921692

# %%
import time

max_iter = 5

# download MNIST
mnist = tf.keras.datasets.mnist

# split into test and train sets
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# normalize to [0,1] by dividing by the max value
x_train, x_test = x_train / 255.0, x_test / 255.0

# further split x_train and y_train into new training and bug fixing sets (50/50)
from sklearn.model_selection import train_test_split
x_train, x_bug_fixes, y_train, y_bug_fixes = train_test_split(x_train, y_train, test_size=0.5, random_state=123)

print('Training data shape: ', x_train.shape)
print('Training labels shape: ', y_train.shape)

print('Bug Fixing data shape: ', x_bug_fixes.shape)
print('Bug Fixing labels shape: ', y_bug_fixes.shape)

print('Test data shape: ', x_test.shape)
print('Test labels shape: ', y_test.shape)

# create model layers
model = k.models.Sequential([
  # flatten into a single vector
  k.layers.Flatten(input_shape=(28, 28)),
  # first layer
  k.layers.Dense(28, activation=tf.nn.relu),
  #k.layers.Dropout(0.2),
  # second layer
  k.layers.Dense(28, activation=tf.nn.relu),
  #k.layers.Dropout(0.2),
  # third layer
  #k.layers.Dense(28, activation=tf.nn.relu),
  #k.layers.Dropout(0.2),
  # fourth layer
  #k.layers.Dense(28, activation=tf.nn.relu),
  #k.layers.Dropout(0.2),
  # output layer
  k.layers.Dense(10, activation=tf.nn.softmax)
])

# compile with optimizer, loss, and metrics
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# fit
model.fit(x_train, y_train, epochs=epochs)

# predict test (to get distributions)
y_pred = model.predict(x_test)

# test
test_loss, test_acc = model.evaluate(x_test, y_test, verbose=0)
print('Initial Test Loss: {}, Initial Test Accuracy: {}'.format(test_loss, test_acc))

control_model = replicate_model(model)

control_model.compile(optimizer='adam',
                      loss='sparse_categorical_crossentropy',
                      metrics=['accuracy'])

start = time.time()

i = 0
while i < max_iter:

    # control model with no specialized batch selection
    control_batch_x, control_batch_y = x_bug_fixes[:batch_size], y_bug_fixes[:batch_size]
    control_model.fit(control_batch_x, control_batch_y, epochs=epochs, verbose=0)

    # identify target layer
    print('Identifying target layer...')
    target_layer, cache = Forward_Layer_Select(model, 
                                               x_train, 
                                               y_train, 
                                               x_test, 
                                               y_test, 
                                               epochs, 
                                               similarity_threshold, 
                                               verbose=False)

    feature_models, accuracies, bhattacharyyas, layer_pred = cache

    # breakout eval sets
    out = get_eval_datasets(data = x_test, 
                            labels = y_test, 
                            predictions = layer_pred)

    data_correct, labels_correct, data_incorrect, labels_incorrect, labels_corrected = out

    # generate heatmaps
    labels, heatmaps = get_heatmaps(correct_data = data_correct,
                                    correct_labels = labels_correct,
                                    misclassified_data = data_incorrect, 
                                    misclassified_labels = labels_incorrect, 
                                    misclassified_correct_labels = labels_corrected, 
                                    num_classes = num_classes,
                                    labels = [], 
                                    type = 'hci')

    # identify buggy labels
    accuracies_per_label_target = calculate_acc_for_labels(all_labels = y_test,
                                                           correct_labels = labels_correct,
                                                           num_classes = num_classes,
                                                           labels = [])

    underfit_labels = get_underfit_labels(acc = accuracies_per_label_target,
                                          num_classes = num_classes,
                                          threshold = theta,
                                          labels = []) 


    # select the most faulty underfitting label
    if len(underfit_labels) > 0:
        faultiest_label = get_faultiest_label(underfit_labels)
        print('Creating a batch for faultiest label: {}. There are {} faulty labels in total...'.format(faultiest_label, 
                                                                                                       len(underfit_labels)))
        print('Faulty labels: ', underfit_labels)
    else:
        print('MODE retraining complete!')
        break

    # generate a batch tailored to improving performance on that label
    next_X, next_y, x_bug_fixes, y_bug_fixes = select_next_inputs(bug_fix_data = x_bug_fixes,
                                                                  bug_fix_labels = y_bug_fixes,
                                                                  heatmaps = heatmaps,
                                                                  target_label = faultiest_label,
                                                                  batch_size = batch_size,
                                                                  ratio = alpha,
                                                                  for_underfitting = True,
                                                                  distance_metric = 'dot')

    # train on this new batch
    model.fit(next_X, next_y, epochs=epochs, verbose=1)

    # evaluate performance
    test_loss, test_acc = model.evaluate(x_test, y_test, verbose=0)
    print('Test Loss: {}, Test Accuracy: {}'.format(test_loss, test_acc))

    # repeat until there are no more faulty underfitting labels
    i += 1

    print('{} iterations left...\n'.format(max_iter - i))

print('Control model performance to beat:')  
control_loss, control_acc = control_model.evaluate(x_test, y_test, verbose=0)
print('Control Test Loss: {}, Control Test Accuracy: {}'.format(control_loss, control_acc))

print('That took {} seconds'.format(time.time() - start))
# Out:
# Training data shape:  (30000, 28, 28)
# Training labels shape:  (30000,)
# Bug Fixing data shape:  (30000, 28, 28)
# Bug Fixing labels shape:  (30000,)
# Test data shape:  (10000, 28, 28)
# Test labels shape:  (10000,)
# Epoch 1/3
# 938/938 [==============================] - 4s 3ms/step - loss: 0.4761 - accuracy: 0.8633
# Epoch 2/3
# 938/938 [==============================] - 4s 4ms/step - loss: 0.2238 - accuracy: 0.9346
# Epoch 3/3
# 938/938 [==============================] - 3s 3ms/step - loss: 0.1746 - accuracy: 0.9484
# Initial Test Loss: 0.18033692240715027, Initial Test Accuracy: 0.9453999996185303
# Identifying target layer...
# Target Layer is the Output Layer: <keras.layers.core.dense.Dense object at 0x7f0830c58dd0>.
#  Consider additional training because performance has not yet plateued.
# Creating a batch for faultiest label: 5. There are 7 faulty labels in total...
# Faulty labels:  {2: 0.9341085271317829, 3: 0.9346534653465347, 4: 0.9439918533604889, 5: 0.9192825112107623, 7: 0.9386562804284323, 8: 0.9312114989733059, 9: 0.9306243805748265}
# Bug Fixing Pool - # of samples remaining: 28000
# Epoch 1/3
# 63/63 [==============================] - 0s 2ms/step - loss: 0.1569 - accuracy: 0.9475
# Epoch 2/3
# 63/63 [==============================] - 0s 2ms/step - loss: 0.1112 - accuracy: 0.9605
# Epoch 3/3
# 63/63 [==============================] - 0s 2ms/step - loss: 0.0854 - accuracy: 0.9740
# Test Loss: 0.18221360445022583, Test Accuracy: 0.9448999762535095
# 4 iterations left...
#
# Identifying target layer...
# Target Layer is the Output Layer: <keras.layers.core.dense.Dense object at 0x7f0830c58dd0>.
#  Consider additional training because performance has not yet plateued.
# Creating a batch for faultiest label: 5. There are 8 faulty labels in total...
# Faulty labels:  {2: 0.9496124031007752, 3: 0.9386138613861386, 4: 0.9541751527494908, 5: 0.9114349775784754, 6: 0.9519832985386222, 7: 0.9406037000973709, 8: 0.9219712525667351, 9: 0.9197224975222993}
# Bug Fixing Pool - # of samples remaining: 26000
# Epoch 1/3
# 63/63 [==============================] - 0s 3ms/step - loss: 0.1674 - accuracy: 0.9505
# Epoch 2/3
# 63/63 [==============================] - 0s 3ms/step - loss: 0.1161 - accuracy: 0.9690
# Epoch 3/3
# 63/63 [==============================] - 0s 3ms/step - loss: 0.0859 - accuracy: 0.9765
# Test Loss: 0.19562025368213654, Test Accuracy: 0.9394999742507935
# 3 iterations left...
#
# Identifying target layer...
# Target Layer is the Output Layer: <keras.layers.core.dense.Dense object at 0x7f0830c58dd0>.
#  Consider additional training because performance has not yet plateued.
# Creating a batch for faultiest label: 8. There are 8 faulty labels in total...
# Faulty labels:  {2: 0.937984496124031, 3: 0.9287128712871288, 4: 0.9429735234215886, 5: 0.9248878923766816, 6: 0.954070981210856, 7: 0.9425511197663097, 8: 0.919917864476386, 9: 0.9326065411298315}
# Bug Fixing Pool - # of samples remaining: 24000
# Epoch 1/3
# 63/63 [==============================] - 0s 3ms/step - loss: 0.1350 - accuracy: 0.9570
# Epoch 2/3
# 63/63 [==============================] - 0s 3ms/step - loss: 0.0844 - accuracy: 0.9745
# Epoch 3/3
# 63/63 [==============================] - 0s 3ms/step - loss: 0.0610 - accuracy: 0.9855
# Test Loss: 0.1850387305021286, Test Accuracy: 0.9437000155448914
# 2 iterations left...
#
# Identifying target layer...
# Target Layer is the Output Layer: <keras.layers.core.dense.Dense object at 0x7f0830c58dd0>.
#  Consider additional training because performance has not yet plateued.
# Creating a batch for faultiest label: 8. There are 8 faulty labels in total...
# Faulty labels:  {2: 0.937984496124031, 3: 0.9396039603960396, 4: 0.9358452138492872, 5: 0.9080717488789237, 6: 0.9561586638830898, 7: 0.9454722492697176, 8: 0.9045174537987679, 9: 0.9326065411298315}
# Bug Fixing Pool - # of samples remaining: 22000
# Epoch 1/3
# 63/63 [==============================] - 0s 3ms/step - loss: 0.1835 - accuracy: 0.9505
# Epoch 2/3
# 63/63 [==============================] - 0s 3ms/step - loss: 0.1204 - accuracy: 0.9680
# Epoch 3/3
# 63/63 [==============================] - 0s 3ms/step - loss: 0.0953 - accuracy: 0.9785
# Test Loss: 0.1722124069929123, Test Accuracy: 0.9488000273704529
# 1 iterations left...
#
# Identifying target layer...
# Target Layer is the Output Layer: <keras.layers.core.dense.Dense object at 0x7f0830c58dd0>.
#  Consider additional training because performance has not yet plateued.
# Creating a batch for faultiest label: 5. There are 7 faulty labels in total...
# Faulty labels:  {2: 0.9408914728682171, 3: 0.9237623762376238, 4: 0.9511201629327902, 5: 0.9192825112107623, 7: 0.9298928919182083, 8: 0.9219712525667351, 9: 0.9306243805748265}
# Bug Fixing Pool - # of samples remaining: 20000
# Epoch 1/3
# 63/63 [==============================] - 0s 3ms/step - loss: 0.1691 - accuracy: 0.9465
# Epoch 2/3
# 63/63 [==============================] - 0s 3ms/step - loss: 0.1073 - accuracy: 0.9680
# Epoch 3/3
# 63/63 [==============================] - 0s 3ms/step - loss: 0.0869 - accuracy: 0.9740
# Test Loss: 0.17062585055828094, Test Accuracy: 0.9503999948501587
# 0 iterations left...
#
# Control model performance to beat:
# Control Test Loss: 0.1767101138830185, Control Test Accuracy: 0.9467999935150146
# That took 106.21979713439941 seconds

# %% [markdown]
# ## Visualizations

# %%
sample_misclassifications(misclassified_data = x_test_x, 
                          misclassified_labels = y_pred_x, 
                          misclassified_correct_labels = y_true_x, 
                          num_samples=1, 
                          shuffle=True)
# Out:
# True Label: 9 Prediction: 4

# %%
viz_heatmaps_for_correct_prediction(correct_data = x_test_o,
                                    correct_labels = y_pred_o,
                                    num_classes = num_classes,
                                    labels = [],
                                    cmap = 'seismic')

# %%
viz_heatmaps_for_false_positives(misclassified_data = x_test_x, 
                                 misclassified_correct_labels = y_true_x, 
                                 num_classes = num_classes,
                                 cmap='seismic')

# %%
viz_heatmaps_for_false_negatives(misclassified_data = x_test_x, 
                                 misclassified_labels = y_pred_x, 
                                 num_classes = num_classes,
                                 cmap='seismic')

# %%
DHCI_i_k(correct_data = x_test_o,
         correct_labels = y_pred_o,
         first_label = 1, 
         second_label = 2,
         cmap='seismic')

# %%
DHMI_i(correct_data = x_test_o,
       correct_labels = y_pred_o,
       misclassified_data = x_test_x,
       misclassified_correct_labels = y_true_x, 
       num_classes = num_classes,
       cmap='seismic')

# %%
DHWI_i(correct_data = x_test_o,
       correct_labels = y_pred_o,
       misclassified_data = x_test_x,
       misclassified_labels = y_pred_x, 
       num_classes = num_classes,
       cmap='seismic')

# %%
viz_most_least_similar(bug_fix_data = x_bug_fixes,
                       bug_fix_labels = y_bug_fixes,
                       labels = labels,
                       heatmaps = heatmaps,
                       distance_metric='dot')

# %%
viz_most_least_similar(bug_fix_data = x_bug_fixes,
                       bug_fix_labels = y_bug_fixes,
                       labels = labels,
                       heatmaps = heatmaps,
                       distance_metric='cosine')

# %%
viz_most_least_similar(bug_fix_data = x_bug_fixes,
                       bug_fix_labels = y_bug_fixes,
                       labels = labels,
                       heatmaps = heatmaps,
                       distance_metric='euclidean')

# %%
viz_most_least_similar(bug_fix_data = x_bug_fixes,
                       bug_fix_labels = y_bug_fixes,
                       labels = labels,
                       heatmaps = heatmaps,
                       distance_metric='manhattan')

# %%
viz_most_least_similar(bug_fix_data = x_bug_fixes,
                       bug_fix_labels = y_bug_fixes,
                       labels = labels,
                       heatmaps = heatmaps,
                       distance_metric='minkowski')
# Out:
# Defaut minkowski_power = 3 set...

# %%
viz_most_least_similar(bug_fix_data = x_bug_fixes,
                       bug_fix_labels = y_bug_fixes,
                       labels = labels,
                       heatmaps = heatmaps,
                       distance_metric='minkowski',
                       minkowski_power=5)

# %%
viz_most_least_similar(bug_fix_data = x_bug_fixes,
                       bug_fix_labels = y_bug_fixes,
                       labels = labels,
                       heatmaps = heatmaps,
                       distance_metric='earthmover')

# %%
viz_most_least_similar(bug_fix_data = x_bug_fixes,
                       bug_fix_labels = y_bug_fixes,
                       labels = labels,
                       heatmaps = heatmaps,
                       distance_metric='chebyshev')

# %%
viz_most_least_similar(bug_fix_data = x_bug_fixes,
                       bug_fix_labels = y_bug_fixes,
                       labels = labels,
                       heatmaps = heatmaps,
                       distance_metric='canberra')

# %%
viz_most_least_similar(bug_fix_data = x_bug_fixes,
                       bug_fix_labels = y_bug_fixes,
                       labels = labels,
                       heatmaps = heatmaps,
                       distance_metric='braycurtis')

# %%
for distance_metric in distance_metrics:

    viz_most_similar(bug_fix_data = x_bug_fixes,
                     bug_fix_labels = y_bug_fixes,
                     labels = labels,
                     heatmaps = heatmaps,
                     distance_metric=distance_metric)
# Out:
# Defaut minkowski_power = 3 set...

# %%
for distance_metric in distance_metrics:

    viz_least_similar(bug_fix_data = x_bug_fixes,
                     bug_fix_labels = y_bug_fixes,
                     labels = labels,
                     heatmaps = heatmaps,
                     distance_metric=distance_metric)
# Out:
# Defaut minkowski_power = 3 set...
